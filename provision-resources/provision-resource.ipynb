# %%
# runs in Chameleon Jupyter environment
from chi import server, context

context.version = "1.0" 
context.choose_project()
context.choose_site(default="KVM@TACC")
# Out:
# VBox(children=(Dropdown(description='Select Project', options=('CHI-251409',), value='CHI-251409'), Output()))
# VBox(children=(Dropdown(description='Select Site', index=7, options=('CHI@TACC', 'CHI@UC', 'CHI@EVL', 'CHI@NCA…

# %%
server.update_keypair()
# Out:
# <Keypair: br2543_nyu_edu-jupyter>

# %% [markdown]
# ### BASH

# %%
mkdir -p /work/.local/bin
wget https://releases.hashicorp.com/terraform/1.10.5/terraform_1.10.5_linux_amd64.zip
unzip -o -q terraform_1.10.5_linux_amd64.zip
mv terraform /work/.local/bin
rm terraform_1.10.5_linux_amd64.zip
# Out:
# --2025-05-07 16:47:23--  https://releases.hashicorp.com/terraform/1.10.5/terraform_1.10.5_linux_amd64.zip
# Resolving releases.hashicorp.com (releases.hashicorp.com)... 18.238.171.101, 18.238.171.54, 18.238.171.95, ...
# Connecting to releases.hashicorp.com (releases.hashicorp.com)|18.238.171.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27714924 (26M) [application/zip]
# Saving to: ‘terraform_1.10.5_linux_amd64.zip’
#
# terraform_1.10.5_li 100%[===================>]  26.43M   128MB/s    in 0.2s
#
# 2025-05-07 16:47:23 (128 MB/s) - ‘terraform_1.10.5_linux_amd64.zip’ saved [27714924/27714924]

# %%
export PATH=/work/.local/bin:$PATH
