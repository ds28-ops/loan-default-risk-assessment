# %%
# !pip install hummingbird-ml
# !pip install onnxmltools
# Out:
# Collecting onnxmltools
#   Downloading onnxmltools-1.13.0-py2.py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (from onnxmltools) (2.0.2)
# Requirement already satisfied: onnx in /opt/conda/lib/python3.12/site-packages (from onnxmltools) (1.16.1)
# Requirement already satisfied: onnxconverter-common in /opt/conda/lib/python3.12/site-packages (from onnxmltools) (1.14.0)
# Requirement already satisfied: protobuf>=3.20.2 in /opt/conda/lib/python3.12/site-packages (from onnx->onnxmltools) (3.20.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from onnxconverter-common->onnxmltools) (24.2)
# Downloading onnxmltools-1.13.0-py2.py3-none-any.whl (328 kB)
# Installing collected packages: onnxmltools
# Successfully installed onnxmltools-1.13.0

# %%
import os
import pandas as pd
import numpy as np
import joblib
import mlflow
import mlflow.xgboost
import matplotlib.pyplot as plt

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    precision_recall_fscore_support,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    precision_score,
    recall_score
)
from xgboost import XGBClassifier
from onnxmltools.convert import convert_xgboost
from onnxmltools.convert.common.data_types import FloatTensorType

# %%
config = {
    "run_name": "xgb-kfold-binary-13",
    "n_splits": 2,
    "n_estimators": 150,
    "learning_rate": 0.001,
    "max_depth": 15,
    "random_state": 42,
    "objective": "binary:logistic",
    "eval_metric": "logloss",
    "scale_pos_weight": 6.4,
    "experiment_name": "loan-risk-xgboost",
    "dataset_path": "/mnt/object/train/train_transformed.csv",
    "label_col": "risk_level"
}

# %%
# 3. Load dataset
df = pd.read_csv(config["dataset_path"])
X = df.drop(columns=[config["label_col"]])
y = df[config["label_col"]]  # Already binary-mapped in transform step

# %%
output_dir = os.path.join("models", config["run_name"])
os.makedirs(output_dir, exist_ok=True)

# %%
# 4. Set MLflow experiment
mlflow.set_experiment(config["experiment_name"])
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/1', creation_time=1746921146045, experiment_id='1', last_update_time=1746921146045, lifecycle_stage='active', name='loan-risk-xgboost', tags={}>

# %%
with mlflow.start_run(run_name=config["run_name"]):
    mlflow.log_params({
        "n_estimators": config["n_estimators"],
        "learning_rate": config["learning_rate"],
        "max_depth": config["max_depth"],
        "n_splits": config["n_splits"],
        "scale_pos_weight": config["scale_pos_weight"]
    })

    kf = StratifiedKFold(n_splits=config["n_splits"], shuffle=True, random_state=config["random_state"])
    fold_accuracies = []
    fold_confidences = {0: [], 1: []}
    all_f1_macro = []
    all_f1_weighted = []
    all_preds = []
    all_probs = []
    all_true = []
    all_precision_macro = []
    all_recall_macro = []

    for fold, (train_index, val_index) in enumerate(kf.split(X, y)):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        model = XGBClassifier(
            n_estimators=config["n_estimators"],
            learning_rate=config["learning_rate"],
            max_depth=config["max_depth"],
            random_state=config["random_state"],
            objective=config["objective"],
            eval_metric=config["eval_metric"],
            scale_pos_weight=config["scale_pos_weight"]
        )

        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)
        y_prob = model.predict_proba(X_val)[:, 1]

        all_preds.extend(y_pred)
        all_probs.extend(y_prob)
        all_true.extend(y_val)

        for pred_label, prob in zip(y_pred, y_prob):
            fold_confidences[pred_label].append(prob)

        acc = accuracy_score(y_val, y_pred)
        fold_accuracies.append(acc)
        print(f"Fold {fold+1} Accuracy: {acc:.4f}")
        print(classification_report(y_val, y_pred, target_names=["Low (0)", "High (1)"]))

        f1_macro = f1_score(y_val, y_pred, average="macro", zero_division=0)
        f1_weighted = f1_score(y_val, y_pred, average="weighted", zero_division=0)
        precision_macro = precision_score(y_val, y_pred, average="macro", zero_division=0)
        recall_macro = recall_score(y_val, y_pred, average="macro", zero_division=0)

        all_f1_macro.append(f1_macro)
        all_f1_weighted.append(f1_weighted)
        all_precision_macro.append(precision_macro)
        all_recall_macro.append(recall_macro)

    # Overall metrics
    avg_acc = np.mean(fold_accuracies)
    mlflow.log_metric("avg_kfold_accuracy", avg_acc)
    mlflow.log_metric("avg_f1_macro", np.mean(all_f1_macro))
    mlflow.log_metric("avg_f1_weighted", np.mean(all_f1_weighted))
    mlflow.log_metric("avg_precision_macro", np.mean(all_precision_macro))
    mlflow.log_metric("avg_recall_macro", np.mean(all_recall_macro))

    for class_label in [0, 1]:
        if fold_confidences[class_label]:
            avg_conf = np.mean(fold_confidences[class_label])
            mlflow.log_metric(f"avg_confidence_class_{class_label}", avg_conf)
            print(f"Avg confidence for class {class_label}: {avg_conf:.4f}")

    roc_auc = roc_auc_score(all_true, all_probs)
    mlflow.log_metric("roc_auc_overall", roc_auc)
    print(f"ROC-AUC Overall: {roc_auc:.4f}")

    # Confusion Matrix
    cm = confusion_matrix(all_true, all_preds, labels=[0, 1])
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Low", "High"])
    disp.plot(cmap="Blues", values_format="d")
    plt.title("Confusion Matrix (Overall)")
    cm_path = os.path.join(output_dir, "confusion_matrix.png")
    plt.savefig(cm_path)
    plt.close()
    mlflow.log_artifact(cm_path)

    # Feature Importance
    importances = model.feature_importances_
    feat_imp_df = pd.DataFrame({
        "feature": X.columns,
        "importance": importances
    }).sort_values(by="importance", ascending=False)

    feat_imp_csv = os.path.join(output_dir, "feature_importance.csv")
    feat_imp_df.to_csv(feat_imp_csv, index=False)
    mlflow.log_artifact(feat_imp_csv)

    plot_path = os.path.join(output_dir, "feature_importance_top15.png")
    plt.figure(figsize=(10, 6))
    feat_imp_df.head(15).plot(kind='barh', x='feature', y='importance', legend=False)
    plt.title("Top 15 Feature Importances (XGBoost)")
    plt.tight_layout()
    plt.savefig(plot_path)
    plt.close()
    mlflow.log_artifact(plot_path)

    # Save model (joblib)
    model_path = os.path.join(output_dir, "model.pth")
    joblib.dump(model, model_path)
    mlflow.log_artifact(model_path)

    # Export to ONNX (correct way)
    initial_type = [('float_input', FloatTensorType([None, X.shape[1]]))]
    onnx_model = convert_xgboost(model, initial_types=initial_type)
    onnx_path = os.path.join(output_dir, "model.onnx")
    with open(onnx_path, "wb") as f:
        f.write(onnx_model.SerializeToString())
    mlflow.log_artifact(onnx_path)

    print(f"✅ All artifacts saved to {output_dir}")
    print(f"📊 KFold avg accuracy: {avg_acc:.4f}")
# Out:
# Fold 1 Accuracy: 0.6585
#               precision    recall  f1-score   support
#
#      Low (0)       0.92      0.66      0.77    782027
#     High (1)       0.23      0.65      0.34    122240
#
#     accuracy                           0.66    904267
#    macro avg       0.58      0.65      0.55    904267
# weighted avg       0.83      0.66      0.71    904267
#
# Fold 2 Accuracy: 0.6514
#               precision    recall  f1-score   support
#
#      Low (0)       0.92      0.65      0.76    782027
#     High (1)       0.23      0.66      0.34    122240
#
#     accuracy                           0.65    904267
#    macro avg       0.58      0.65      0.55    904267
# weighted avg       0.83      0.65      0.71    904267
#
# Avg confidence for class 0: 0.4631
# Avg confidence for class 1: 0.5208
# ROC-AUC Overall: 0.7106
# 🏃 View run xgb-kfold-binary-13 at: http://129.114.25.120:8000/#/experiments/1/runs/19ade86ae7634e788676cd21117edbfa
# 🧪 View experiment at: http://129.114.25.120:8000/#/experiments/1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.12/site-packages/onnxmltools/convert/xgboost/operator_converters/XGBoost.py:114, in XGBConverter._add_node(attr_pairs, is_classifier, tree_id, tree_weight, node_id, feature_id, mode, value, true_child_id, false_child_id, weights, weight_id_bias, missing, hitrate)
#     113 try:
# --> 114     feature_id = int(float(feature_id))
#     115 except ValueError:
#
# ValueError: could not convert string to float: 'sub_grade'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 116
#     114 # Export to ONNX (correct way)
#     115 initial_type = [('float_input', FloatTensorType([None, X.shape[1]]))]
# --> 116 onnx_model = convert_xgboost(model, initial_types=initial_type)
#     117 onnx_path = os.path.join(output_dir, "model.onnx")
#     118 with open(onnx_path, "wb") as f:
#
# File /opt/conda/lib/python3.12/site-packages/onnxmltools/convert/main.py:327, in convert_xgboost(*args, **kwargs)
#     321     raise RuntimeError(
#     322         "xgboost is not installed. Please install xgboost to use this feature."
#     323     )
#     325 from .xgboost.convert import convert
# --> 327 return convert(*args, **kwargs)
#
# File /opt/conda/lib/python3.12/site-packages/onnxmltools/convert/xgboost/convert.py:63, in convert(model, name, initial_types, doc_string, target_opset, targeted_onnx, custom_conversion_functions, custom_shape_calculators)
#      55 topology = parse_xgboost(
#      56     model,
#      57     initial_types,
#    (...)
#      60     custom_shape_calculators,
#      61 )
#      62 topology.compile()
# ---> 63 onnx_model = convert_topology(
#      64     topology, name, doc_string, target_opset, targeted_onnx
#      65 )
#      66 opsets = {d.domain: d.version for d in onnx_model.opset_import}
#      67 if "" in opsets and opsets[""] < 9 and target_opset >= 9:
#      68     # a bug?
#
# File /opt/conda/lib/python3.12/site-packages/onnxconverter_common/topology.py:776, in convert_topology(topology, model_name, doc_string, target_opset, targeted_onnx, channel_first_inputs)
#     773         topology.custom_conversion_functions[operator.type](scope, operator, container)
#     774     else:
#     775         # Convert the selected operator into some ONNX objects and save them into the container
# --> 776         get_converter(operator.type)(scope, operator, container)
#     778 # When calling ModelComponentContainer's add_initializer(...), nothing is added into the input list.
#     779 # However, for ONNX target opset < 9, initializers should also be model's (GraphProto) inputs.
#     780 # Thus, we create ValueInfoProto objects from initializers (type: TensorProto) directly and
#     781 # then add them into model's input list.
#     782 extra_inputs = []  # ValueInfoProto list of the initializers
#
# File /opt/conda/lib/python3.12/site-packages/onnxmltools/convert/xgboost/operator_converters/XGBoost.py:434, in convert_xgboost(scope, operator, container)
#     432     cls = XGBRegressorConverter
#     433 cls.validate(xgb_node)
# --> 434 cls.convert(scope, operator, container)
#
# File /opt/conda/lib/python3.12/site-packages/onnxmltools/convert/xgboost/operator_converters/XGBoost.py:310, in XGBClassifierConverter.convert(scope, operator, container)
#     307 num_class = params.get("num_class", None)
#     309 attr_pairs = XGBClassifierConverter._get_default_tree_attribute_pairs()
# --> 310 XGBConverter.fill_tree_attributes(
#     311     js_trees, attr_pairs, [1 for _ in js_trees], True
#     312 )
#     313 if num_class is not None:
#     314     ncl = num_class
#
# File /opt/conda/lib/python3.12/site-packages/onnxmltools/convert/xgboost/operator_converters/XGBoost.py:219, in XGBConverter.fill_tree_attributes(js_xgb_node, attr_pairs, tree_weights, is_classifier)
#     217 for treeid, (jstree, w) in enumerate(zip(js_xgb_node, tree_weights)):
#     218     remap = XGBConverter._remap_nodeid(jstree)
# --> 219     XGBConverter._fill_node_attributes(
#     220         treeid, w, jstree, attr_pairs, is_classifier, remap
#     221     )
#
# File /opt/conda/lib/python3.12/site-packages/onnxmltools/convert/xgboost/operator_converters/XGBoost.py:157, in XGBConverter._fill_node_attributes(treeid, tree_weight, jsnode, attr_pairs, is_classifier, remap)
#     152 @staticmethod
#     153 def _fill_node_attributes(
#     154     treeid, tree_weight, jsnode, attr_pairs, is_classifier, remap
#     155 ):
#     156     if "children" in jsnode:
# --> 157         XGBConverter._add_node(
#     158             attr_pairs=attr_pairs,
#     159             is_classifier=is_classifier,
#     160             tree_id=treeid,
#     161             tree_weight=tree_weight,
#     162             value=jsnode["split_condition"],
#     163             node_id=remap[jsnode["nodeid"]],
#     164             feature_id=jsnode["split"],
#     165             mode="BRANCH_LT",  # 'BRANCH_LEQ' --> is for sklearn
#     166             true_child_id=remap[jsnode["yes"]],  # ['children'][0]['nodeid'],
#     167             false_child_id=remap[jsnode["no"]],  # ['children'][1]['nodeid'],
#     168             weights=None,
#     169             weight_id_bias=None,
#     170             missing=jsnode.get("missing", -1) == jsnode["yes"],
#     171             hitrate=jsnode.get("cover", 0),
#     172         )
#     174         for ch in jsnode["children"]:
#     175             if "children" in ch or "leaf" in ch:
#
# File /opt/conda/lib/python3.12/site-packages/onnxmltools/convert/xgboost/operator_converters/XGBoost.py:116, in XGBConverter._add_node(attr_pairs, is_classifier, tree_id, tree_weight, node_id, feature_id, mode, value, true_child_id, false_child_id, weights, weight_id_bias, missing, hitrate)
#     114             feature_id = int(float(feature_id))
#     115         except ValueError:
# --> 116             raise RuntimeError(
#     117                 "Unable to interpret '{0}', feature "
#     118                 "names should follow pattern 'f%d'.".format(feature_id)
#     119             )
#     121 # Split condition for sklearn
#     122 # * if X_ptr[X_sample_stride * i + X_fx_stride * node.feature] <= node.threshold:
#     123 # * https://github.com/scikit-learn/scikit-learn/blob/main/sklearn/tree/_tree.pyx#L946
#     124 # Split condition for xgboost
#     125 # * if (fvalue < split_value)
#     126 # * https://github.com/dmlc/xgboost/blob/main/include/xgboost/tree_model.h#L804
#     128 attr_pairs["nodes_treeids"].append(tree_id)
#
# RuntimeError: Unable to interpret 'sub_grade', feature names should follow pattern 'f%d'.
